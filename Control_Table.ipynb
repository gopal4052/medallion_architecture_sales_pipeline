# %%
# %sql

create table if not exists data_engineering.table_metadata.Control_Table
(pipeline_name string,
 last_run_time timestamp,
 status string)
Using Delta;

# %%
# %sql

DELETE FROM data_engineering.table_metadata.Control_Table
WHERE pipeline_name = 'medallion_architecture_sales_pipeline';

INSERT INTO data_engineering.table_metadata.Control_Table
VALUES (
  'medallion_architecture_sales_pipeline',
  TIMESTAMP '1900-01-01 00:00:00',
  'INIT'
);

# %%
# %sql

SELECT *
FROM data_engineering.gold_layer.total_sales_per_city
ORDER BY city;

select * from data_engineering.table_metadata.Control_Table;

# %%
# %sql
SELECT city, SUM(sales) AS expected_total
FROM data_engineering.silver_layer.silver_sales
GROUP BY city
ORDER BY city;
